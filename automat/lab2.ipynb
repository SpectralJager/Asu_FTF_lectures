# %%
# var 3
Ts = 16.4
K = 0.08
TR = 1
Toc = 3

# %%
import numpy as np
import scipy.signal as signal
import control as c
import matplotlib.pyplot as plt

# %%
P = c.tf(K, [Ts, 1, 0])
R0 = c.tf(1, [TR, 0])
R = c.feedback(R0, 1)
R
# Out:
# TransferFunction(array([1]), array([1, 1]))

# %%
G = P*R
G
# Out:
# TransferFunction(array([0.08]), array([16.4, 17.4,  1. ,  0. ]))

# %%
H = c.tf(1, [Toc, 1])
H
# Out:
# TransferFunction(array([1]), array([3, 1]))

# %%
L = G*H
L
# Out:
# TransferFunction(array([0.08]), array([49.2, 68.6, 20.4,  1. ,  0. ]))

# %%
_ = c.bode_plot(L)

# %%
t = np.linspace(0,200,1000)

# %%
c.ss()
